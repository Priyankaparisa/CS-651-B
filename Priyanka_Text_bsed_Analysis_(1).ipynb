# %%
# Use regex to remove stop words
import re

# Sample dataset
dataset = """
ReviewID,ReviewText,Rating
1,"One of the best movies I've ever seen. The plot was captivating and the acting was superb. I highly recommend it!",5
2,"This movie was okay. It had some good moments, but overall it was a bit disappointing. I expected more from the director.",3
3,"Absolutely terrible. I couldn't even finish watching it. Save yourself the trouble and skip this one.",1
4,"A true masterpiece. The cinematography was stunning and the story was deeply moving. I was completely engrossed from start to finish.",5
5,"I enjoyed this movie. It was entertaining and kept me engaged throughout. I would watch it again.",4
6,"Not my cup of tea. The pacing was off and the characters were underdeveloped. I wouldn't recommend it.",2
7,"Disappointing. The trailer looked promising, but the movie itself fell flat. The plot was predictable and the dialogue felt forced.",2
8,"Brilliantly crafted. The performances were outstanding and the storytelling was gripping. I was on the edge of my seat the entire time.",5
9,"Decent movie. It had its moments, but it didn't leave a lasting impression. I wouldn't rush to see it again.",3
10,"Waste of time. The acting was wooden and the plot was nonsensical. I couldn't wait for it to be over.",1
"""

# Define stop words
stop_words = {'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"}

# Function to remove stop words using regex
def remove_stop_words(text):
    # Convert text to lowercase
    text = text.lower()
    # Remove stop words using regex
    text = re.sub(r'\b(?:{})\b'.format('|'.join(stop_words)), '', text)
    return text

# Split dataset into lines and process each line
lines = dataset.strip().split('\n')
for line in lines:
    parts = line.split(',')
    review_text = parts[1]  # Assuming the review text is in the second column
    # Remove stop words
    cleaned_text = remove_stop_words(review_text)
    print(cleaned_text)
# Out:
# reviewtext
# "one   best movies ' ever seen.  plot  captivating   acting  superb.  highly recommend !"
# " movie  okay.    good moments
# "absolutely terrible.  ' even finish watching . save   trouble  skip  one."
# " true masterpiece.  cinematography  stunning   story  deeply moving.   completely engrossed  start  finish."
# " enjoyed  movie.   entertaining  kept  engaged throughout.  would watch  ."
# "  cup  tea.  pacing     characters  underdeveloped.  ' recommend ."
# "disappointing.  trailer looked promising
# "brilliantly crafted.  performances  outstanding   storytelling  gripping.     edge   seat  entire time."
# "decent movie.    moments
# "waste  time.  acting  wooden   plot  nonsensical.  ' wait     ."

# %%
#Make a detailed notebook containing all the statistical operations and formvarious kinds of plots depicting the data or the business focused on
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the movies dataset as a list of dictionaries
movies_data = [
    {'ID': 1, 'Title': 'The Shawshank Redemption', 'Genre': 'Drama', 'Year': 1994, 'Rating': 9.3, 'Votes': 2117180},
    {'ID': 2, 'Title': 'The Godfather', 'Genre': 'Crime', 'Year': 1972, 'Rating': 9.2, 'Votes': 1450334},
    {'ID': 3, 'Title': 'The Dark Knight', 'Genre': 'Action', 'Year': 2008, 'Rating': 9.0, 'Votes': 2126535},
    {'ID': 4, 'Title': 'Schindler\'s List', 'Genre': 'Biography', 'Year': 1993, 'Rating': 8.9, 'Votes': 1141602},
    {'ID': 5, 'Title': 'The Lord of the Rings: The Return of the King', 'Genre': 'Adventure', 'Year': 2003, 'Rating': 8.9, 'Votes': 1610956},
    {'ID': 6, 'Title': 'Pulp Fiction', 'Genre': 'Crime', 'Year': 1994, 'Rating': 8.9, 'Votes': 1819176},
    {'ID': 7, 'Title': 'Fight Club', 'Genre': 'Drama', 'Year': 1999, 'Rating': 8.8, 'Votes': 1855784},
    {'ID': 8, 'Title': 'Forrest Gump', 'Genre': 'Drama', 'Year': 1994, 'Rating': 8.8, 'Votes': 1768347},
    {'ID': 9, 'Title': 'Inception', 'Genre': 'Action', 'Year': 2010, 'Rating': 8.8, 'Votes': 1984577},
    {'ID': 10, 'Title': 'The Matrix', 'Genre': 'Action', 'Year': 1999, 'Rating': 8.7, 'Votes': 1699197}
]

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(movies_data)

# Data exploration
print(df.head())
print(df.info())
print(df.describe())

# Statistical operations
numeric_stats = df.describe()

# Visualization
plt.figure(figsize=(10, 6))
sns.histplot(df['Rating'], bins=20, kde=True)
plt.title('Distribution of Movie Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='Genre', y='Rating', data=df)
plt.title('Boxplot of Movie Ratings by Genre')
plt.xlabel('Genre')
plt.ylabel('Rating')
plt.xticks(rotation=45)
plt.show()

# Business insights
print("Business Insights:")
print("- The average rating of movies in the dataset is:", numeric_stats.loc['mean', 'Rating'])
print("- There is variability in ratings between different genres of movies.")
# Out:
#    ID                                          Title      Genre  Year  Rating  \
# 0   1                       The Shawshank Redemption      Drama  1994     9.3
# 1   2                                  The Godfather      Crime  1972     9.2
# 2   3                                The Dark Knight     Action  2008     9.0
# 3   4                               Schindler's List  Biography  1993     8.9
# 4   5  The Lord of the Rings: The Return of the King  Adventure  2003     8.9
#
#      Votes
# 0  2117180
# 1  1450334
# 2  2126535
# 3  1141602
# 4  1610956
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      10 non-null     int64
#  1   Title   10 non-null     object
#  2   Genre   10 non-null     object
#  3   Year    10 non-null     int64
#  4   Rating  10 non-null     float64
#  5   Votes   10 non-null     int64
# ...

# %%
#Create pipeline, remove stop words, word frequency analysis and wordclouds.
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Download NLTK stopwords
nltk.download('stopwords')
nltk.download('punkt')

# Load the movie review dataset
movies_data = [
    {'ID': 1, 'Title': 'The Shawshank Redemption', 'Genre': 'Drama', 'Year': 1994, 'Rating': 9.3, 'Votes': 2117180, 'Review': 'One of the best movies ever made. The acting is phenomenal and the story is gripping.'},
    {'ID': 2, 'Title': 'The Godfather', 'Genre': 'Crime', 'Year': 1972, 'Rating': 9.2, 'Votes': 1450334, 'Review': 'A classic crime drama with unforgettable characters and an iconic soundtrack.'},
    {'ID': 3, 'Title': 'The Dark Knight', 'Genre': 'Action', 'Year': 2008, 'Rating': 9.0, 'Votes': 2126535, 'Review': 'A thrilling action-packed movie with an amazing performance by Heath Ledger as the Joker.'},
    {'ID': 4, 'Title': "Schindler's List", 'Genre': 'Biography', 'Year': 1993, 'Rating': 8.9, 'Votes': 1141602, 'Review': 'A powerful and moving portrayal of Oskar Schindler and his efforts to save Jews during the Holocaust.'},
    {'ID': 5, 'Title': 'The Lord of the Rings: The Return of the King', 'Genre': 'Adventure', 'Year': 2003, 'Rating': 8.9, 'Votes': 1610956, 'Review': 'An epic conclusion to the Lord of the Rings trilogy, with stunning visuals and epic battles.'},
    {'ID': 6, 'Title': 'Pulp Fiction', 'Genre': 'Crime', 'Year': 1994, 'Rating': 8.9, 'Votes': 1819176, 'Review': 'A non-linear crime drama with witty dialogue and memorable characters.'},
    {'ID': 7, 'Title': 'Fight Club', 'Genre': 'Drama', 'Year': 1999, 'Rating': 8.8, 'Votes': 1855784, 'Review': 'A thought-provoking movie that explores themes of identity and consumerism.'},
    {'ID': 8, 'Title': 'Forrest Gump', 'Genre': 'Drama', 'Year': 1994, 'Rating': 8.8, 'Votes': 1768347, 'Review': 'An uplifting and heartwarming tale of a man who experiences life to the fullest despite his intellectual challenges.'},
    {'ID': 9, 'Title': 'Inception', 'Genre': 'Action', 'Year': 2010, 'Rating': 8.8, 'Votes': 1984577, 'Review': 'A mind-bending sci-fi thriller with stunning visual effects and a complex narrative.'},
    {'ID': 10, 'Title': 'The Matrix', 'Genre': 'Action', 'Year': 1999, 'Rating': 8.7, 'Votes': 1699197, 'Review': 'A groundbreaking action movie with innovative special effects and a thought-provoking story.'}
]

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(movies_data)

# Define stop words
stop_words = set(stopwords.words('english'))

# Define function to remove stop words
def remove_stopwords(text):
    tokens = word_tokenize(text)
    filtered_text = [word for word in tokens if word.lower() not in stop_words]
    return ' '.join(filtered_text)

# Define function for word frequency analysis
def word_frequency(text):
    tokens = word_tokenize(text)
    freq_dist = nltk.FreqDist(tokens)
    return freq_dist

# Define function to generate word cloud
def generate_wordcloud(text):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(10, 6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# Define pipeline
def text_processing_pipeline(text):
    text = remove_stopwords(text)
    freq_dist = word_frequency(text)
    generate_wordcloud(text)
    return freq_dist

# Apply pipeline to movie reviews
for index, row in df.iterrows():
    print("Title:", row['Title'])
    print("Review:", row['Review'])
    freq_dist = text_processing_pipeline(row['Review'])
    print("Word Frequencies:", freq_dist)
    print("="*50)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Title: The Shawshank Redemption
# Review: One of the best movies ever made. The acting is phenomenal and the story is gripping.
# Word Frequencies: <FreqDist with 10 samples and 11 outcomes>
# ...
# Title: The Godfather
# Review: A classic crime drama with unforgettable characters and an iconic soundtrack.
# Word Frequencies: <FreqDist with 8 samples and 8 outcomes>
# ...
# Title: The Dark Knight
# Review: A thrilling action-packed movie with an amazing performance by Heath Ledger as the Joker.
# Word Frequencies: <FreqDist with 9 samples and 9 outcomes>
# ...
# Title: Schindler's List
# Review: A powerful and moving portrayal of Oskar Schindler and his efforts to save Jews during the Holocaust.
# Word Frequencies: <FreqDist with 10 samples and 10 outcomes>
# ...

# %%
# Pick 5 random strings which we will encounter in our day-to-day life as adata scientist and write regex to identify them and sort, provide an exampleand result of the regex for each string. (
import re

# Define updated example strings
updated_example_strings = [
    "priyankaparisa36@gmail.com",
    "jahnavi",
    "2024-02-14",
    "192.168.1.1"
]

# Define regex patterns for each example type
regex_patterns = [
    r'^[\w\.-]+@[\w\.-]+\.\w+$', # Email address
    r'^[a-zA-Z_][a-zA-Z0-9_]*$',  # Variable name in Python
    r'^\d{4}-\d{2}-\d{2}$',        # Date in YYYY-MM-DD format
    r'^((25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\.){3}(25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)$', # IP address (IPv4)
    r'^(https?://)?(www\.)?([\w-]+\.[\w-]+)(/[\w- ./?%&=]*)?$' # URL
]

# Test regex patterns on updated example strings
for i, string in enumerate(updated_example_strings):
    matched = re.match(regex_patterns[i], string)
    print(f"Updated Example String: {string}")
    print(f"Regex Pattern: {regex_patterns[i]}")
    print("Result: Matched" if matched else "Result: Not matched")
    print("="*50)
# Out:
# Updated Example String: priyankaparisa36@gmail.com
# Regex Pattern: ^[\w\.-]+@[\w\.-]+\.\w+$
# Result: Matched
# ...
# Updated Example String: jahnavi
# Regex Pattern: ^[a-zA-Z_][a-zA-Z0-9_]*$
# Result: Matched
# ...
# Updated Example String: 2024-02-14
# Regex Pattern: ^\d{4}-\d{2}-\d{2}$
# Result: Matched
# ...
# Updated Example String: 192.168.1.1
# Regex Pattern: ^((25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\.){3}(25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)$
# Result: Matched
# ...

# %%
#Sentiment analysis
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# Download the VADER lexicon for sentiment analysis
nltk.download('vader_lexicon')

# Define the movie review dataset
movie_reviews = [
    "The movie was fantastic! The acting was superb, and the plot kept me on the edge of my seat the entire time.",
    "I found the movie to be quite boring. The story was predictable, and the characters lacked depth.",
    "This film exceeded my expectations. The cinematography was stunning, and the performances were captivating.",
    "I couldn't stand this movie. The dialogue felt forced, and the pacing was all over the place.",
    "One of the best movies I've seen in years. The storytelling was masterful, and the emotional depth was unparalleled.",
    "I was disappointed by this movie. The trailers hyped it up too much, and it didn't deliver on its promises.",
    "The movie had its moments, but overall, it fell flat for me. The plot was convoluted, and the ending was unsatisfying.",
    "I laughed, I cried, and I left the theater feeling deeply moved. This movie touched my heart in ways I never expected.",
    "I'm still processing my thoughts on this movie. It's definitely one that will stay with me for a long time.",
    "Avoid this movie at all costs. It's a complete waste of time and money."
]

# Initialize the sentiment intensity analyzer
sid = SentimentIntensityAnalyzer()

# Perform sentiment analysis on each movie review
for i, review in enumerate(movie_reviews):
    # Analyze the sentiment of the review
    sentiment_scores = sid.polarity_scores(review)

    # Determine the sentiment label based on the compound score
    if sentiment_scores['compound'] >= 0.05:
        sentiment_label = 'Positive'
    elif sentiment_scores['compound'] <= -0.05:
        sentiment_label = 'Negative'
    else:
        sentiment_label = 'Neutral'

    # Print the sentiment analysis results
    print(f"Review {i+1}: {review}")
    print(f"Sentiment Score: {sentiment_scores['compound']}")
    print(f"Sentiment Label: {sentiment_label}")
    print("=" * 50)
# Out:
# Review 1: The movie was fantastic! The acting was superb, and the plot kept me on the edge of my seat the entire time.
# Sentiment Score: 0.8398
# Sentiment Label: Positive
# ...
# Review 2: I found the movie to be quite boring. The story was predictable, and the characters lacked depth.
# Sentiment Score: -0.3804
# Sentiment Label: Negative
# ...
# Review 3: This film exceeded my expectations. The cinematography was stunning, and the performances were captivating.
# Sentiment Score: 0.3818
# Sentiment Label: Positive
# ...
# Review 4: I couldn't stand this movie. The dialogue felt forced, and the pacing was all over the place.
# Sentiment Score: -0.4588
# Sentiment Label: Negative
# ...
# Review 5: One of the best movies I've seen in years. The storytelling was masterful, and the emotional depth was unparalleled.
# Sentiment Score: 0.7003
# Sentiment Label: Positive
# ...
# Review 6: I was disappointed by this movie. The trailers hyped it up too much, and it didn't deliver on its promises.
# ...

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

# Download the VADER lexicon for sentiment analysis
nltk.download('vader_lexicon')

# Define the movie review dataset
movie_reviews = [
    "The movie was fantastic! The acting was superb, and the plot kept me on the edge of my seat the entire time.",
    "I found the movie to be quite boring. The story was predictable, and the characters lacked depth.",
    "This film exceeded my expectations. The cinematography was stunning, and the performances were captivating.",
    "I couldn't stand this movie. The dialogue felt forced, and the pacing was all over the place.",
    "One of the best movies I've seen in years. The storytelling was masterful, and the emotional depth was unparalleled.",
    "I was disappointed by this movie. The trailers hyped it up too much, and it didn't deliver on its promises.",
    "The movie had its moments, but overall, it fell flat for me. The plot was convoluted, and the ending was unsatisfying.",
    "I laughed, I cried, and I left the theater feeling deeply moved. This movie touched my heart in ways I never expected.",
    "I'm still processing my thoughts on this movie. It's definitely one that will stay with me for a long time.",
    "Avoid this movie at all costs. It's a complete waste of time and money."
]

# Initialize the sentiment intensity analyzer
sid = SentimentIntensityAnalyzer()

# Initialize lists to store sentiment scores and labels
sentiment_scores = []
sentiment_labels = []

# Perform sentiment analysis using the SentimentIntensityAnalyzer on each movie review
for review in movie_reviews:
    # Analyze the sentiment of the review
    sentiment_scores.append(sid.polarity_scores(review)['compound'])

    # Determine the sentiment label based on the compound score
    if sentiment_scores[-1] >= 0.05:
        sentiment_labels.append('Positive')
    elif sentiment_scores[-1] <= -0.05:
        sentiment_labels.append('Negative')
    else:
        sentiment_labels.append('Neutral')

# Plot the distribution of sentiment labels
plt.figure(figsize=(8, 5))
plt.hist(sentiment_labels, bins=3, alpha=0.7)
plt.title('Distribution of Sentiment Labels in Movie Reviews')
plt.xlabel('Sentiment Label')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Plot the distribution of sentiment scores
plt.figure(figsize=(8, 5))
plt.hist(sentiment_scores, bins=10, alpha=0.7, color='orange')
plt.title('Distribution of Sentiment Scores in Movie Reviews')
plt.xlabel('Sentiment Score')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
#Bing liu score.
# Define movie review dataset
movie_reviews = [
    "The movie was fantastic! The acting was superb, and the plot kept me on the edge of my seat the entire time.",
    "I found the movie to be quite boring. The story was predictable, and the characters lacked depth.",
    "This film exceeded my expectations. The cinematography was stunning, and the performances were captivating.",
    "I couldn't stand this movie. The dialogue felt forced, and the pacing was all over the place.",
    "One of the best movies I've seen in years. The storytelling was masterful, and the emotional depth was unparalleled.",
    "I was disappointed by this movie. The trailers hyped it up too much, and it didn't deliver on its promises.",
    "The movie had its moments, but overall, it fell flat for me. The plot was convoluted, and the ending was unsatisfying.",
    "I laughed, I cried, and I left the theater feeling deeply moved. This movie touched my heart in ways I never expected.",
    "I'm still processing my thoughts on this movie. It's definitely one that will stay with me for a long time.",
    "Avoid this movie at all costs. It's a complete waste of time and money."
]

# Define positive and negative word lists from Bing Liu lexicon
positive_words = set([
    "fantastic", "superb", "captivating", "masterful", "stunning", "moved", "touching", "best", "exceeded", "unexpected"
])

negative_words = set([
    "boring", "predictable", "lacked", "disappointed", "forced", "convoluted", "unsatisfying", "avoid", "waste"
])

# Define function to calculate Bing Liu sentiment score for a given review
def bing_liu_sentiment(review):
    # Tokenize the review into words
    words = review.lower().split()

    # Count occurrences of positive and negative words
    positive_count = sum(1 for word in words if word in positive_words)
    negative_count = sum(1 for word in words if word in negative_words)

    # Calculate sentiment score based on word counts
    score = positive_count - negative_count

    return score

# Perform sentiment analysis using Bing Liu lexicon on each movie review
for i, review in enumerate(movie_reviews):
    # Calculate Bing Liu sentiment score for the review
    score = bing_liu_sentiment(review)

    # Determine sentiment label based on score
    if score > 0:
        sentiment_label = 'Positive'
    elif score < 0:
        sentiment_label = 'Negative'
    else:
        sentiment_label = 'Neutral'

    # Print sentiment analysis results
    print(f"Review {i+1}: {review}")
    print(f"Bing Liu Sentiment Score: {score}")
    print(f"Sentiment Label: {sentiment_label}")
    print("=" * 50)
# Out:
# Review 1: The movie was fantastic! The acting was superb, and the plot kept me on the edge of my seat the entire time.
# Bing Liu Sentiment Score: 0
# Sentiment Label: Neutral
# ...
# Review 2: I found the movie to be quite boring. The story was predictable, and the characters lacked depth.
# Bing Liu Sentiment Score: -1
# Sentiment Label: Negative
# ...
# Review 3: This film exceeded my expectations. The cinematography was stunning, and the performances were captivating.
# Bing Liu Sentiment Score: 1
# Sentiment Label: Positive
# ...
# Review 4: I couldn't stand this movie. The dialogue felt forced, and the pacing was all over the place.
# Bing Liu Sentiment Score: 0
# Sentiment Label: Neutral
# ...
# Review 5: One of the best movies I've seen in years. The storytelling was masterful, and the emotional depth was unparalleled.
# Bing Liu Sentiment Score: 1
# Sentiment Label: Positive
# ...
# Review 6: I was disappointed by this movie. The trailers hyped it up too much, and it didn't deliver on its promises.
# ...

# %%
import matplotlib.pyplot as plt

# Define the movie review dataset
movie_reviews = [
    "The movie was fantastic! The acting was superb, and the plot kept me on the edge of my seat the entire time.",
    "I found the movie to be quite boring. The story was predictable, and the characters lacked depth.",
    "This film exceeded my expectations. The cinematography was stunning, and the performances were captivating.",
    "I couldn't stand this movie. The dialogue felt forced, and the pacing was all over the place.",
    "One of the best movies I've seen in years. The storytelling was masterful, and the emotional depth was unparalleled.",
    "I was disappointed by this movie. The trailers hyped it up too much, and it didn't deliver on its promises.",
    "The movie had its moments, but overall, it fell flat for me. The plot was convoluted, and the ending was unsatisfying.",
    "I laughed, I cried, and I left the theater feeling deeply moved. This movie touched my heart in ways I never expected.",
    "I'm still processing my thoughts on this movie. It's definitely one that will stay with me for a long time.",
    "Avoid this movie at all costs. It's a complete waste of time and money."
]

# Define positive and negative word lists from Bing Liu lexicon
positive_words = set([
    "fantastic", "superb", "captivating", "masterful", "stunning", "moved", "touching", "best", "exceeded", "unexpected"
])

negative_words = set([
    "boring", "predictable", "lacked", "disappointed", "forced", "convoluted", "unsatisfying", "avoid", "waste"
])

# Define function to calculate Bing Liu sentiment score for a given review
def bing_liu_sentiment(review):
    # Tokenize the review into words
    words = review.lower().split()

    # Count occurrences of positive and negative words
    positive_count = sum(1 for word in words if word in positive_words)
    negative_count = sum(1 for word in words if word in negative_words)

    # Calculate sentiment score based on word counts
    score = positive_count - negative_count

    return score

# Initialize counters for sentiment labels
positive_count = 0
negative_count = 0
neutral_count = 0

# Perform sentiment analysis using Bing Liu lexicon on each movie review
sentiment_scores = []
for review in movie_reviews:
    # Calculate Bing Liu sentiment score for the review
    score = bing_liu_sentiment(review)
    sentiment_scores.append(score)

    # Update sentiment label counts
    if score > 0:
        positive_count += 1
    elif score < 0:
        negative_count += 1
    else:
        neutral_count += 1

# Plot the distribution of sentiment labels
labels = ['Positive', 'Negative', 'Neutral']
counts = [positive_count, negative_count, neutral_count]

plt.figure(figsize=(8, 5))
plt.bar(labels, counts, color=['green', 'red', 'blue'])
plt.title('Distribution of Sentiment Labels in Movie Reviews')
plt.xlabel('Sentiment Label')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Plot the distribution of Bing Liu sentiment scores
plt.figure(figsize=(8, 5))
plt.hist(sentiment_scores, bins=range(min(sentiment_scores), max(sentiment_scores) + 1), color='orange', alpha=0.7)
plt.title('Distribution of Bing Liu Sentiment Scores in Movie Reviews')
plt.xlabel('Sentiment Score')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
